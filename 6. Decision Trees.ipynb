# %%
#Training and Visualizing a Decision Tree

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

# %%
iris = load_iris()
X = iris.data[:, 2:]
y = iris.target

tree_clf = DecisionTreeClassifier(max_depth=2)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    tree_clf,
    out_file="iris_tree.dot",  # 'image_path(...)' hata kar direct string de di
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True,
    filled=True
)

# %%
#Making Predictions

# %%
#Estimating Class Probabilities

# %%
tree_clf.predict_proba([[5, 1.5]])
# Out:
# array([[0.        , 0.90740741, 0.09259259]])

# %%
tree_clf.predict([[5, 1.5]])
# Out:
# array([1])

# %%
#The CART Training Algorithm

# %%
#Regression

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(X, y)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
import numpy as np

import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor

np.random.seed(42)
X = np.sort(np.random.randn(150, 1), axis=0)
y = (X - 0.5)**2 + np.random.randn(150, 1) / 10

tree_reg1 = DecisionTreeRegressor(random_state = 42)
tree_reg2 = DecisionTreeRegressor(random_state = 42, min_samples_leaf=10)
tree_reg1.fit(X, y)
tree_reg2.fit(X, y)

X_grid = np.linspace(0, 1, 500).reshape(-1, 1)
y_pred1 = tree_reg1.predict(X_grid)
y_pred2 = tree_reg2.predict(X_grid)

fig, axes = plt.subplots(ncols=2, figsize=(12, 4), sharey=True)

axes[0].plot(X, y, "b.")
axes[0].plot(X_grid, y_pred1, "r-", linewidth=2, label=r"$\hat{y}$")
axes[0].set_title("min_samples_leaf=10")


axes[1].plot(X, y, "b.")
axes[1].plot(X_grid, y_pred2, "r-", linewidth=3)
axes[1].set_title("min_samples_leaf=10")


plt.show()

# %%
#Instability
